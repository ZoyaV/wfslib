# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import sys
sys.path.append("../") 
from wfslib.geometry import Geometry
from wfslib.wfs import WFSData
# Out:
# C:\Users\Zoya\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from wfslib.wfs import WFSData

path = "data/bad_img3.tiff"

arr = np.array(Image.open(path))[500:1500, 500:1500]
arr = np.expand_dims(arr, 0)
wfs = WFSData(arr)
wfs.geometry.set_options(shift=(-25, -35))

plt.imshow(arr[0])
wfs.show_geometry()
# Out:
# ..\wfslib\wfs.py:107: UserWarning: WARNING: Set the geometry for the file!
#   warn("WARNING: Set the geometry for the file!", UserWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from wfslib.wfs import WFSData

path = "data/bad_img1.tiff"

arr = np.array(Image.open(path))[500:1500, 500:1500]
arr = np.expand_dims(arr, 0)
wfs = WFSData(arr)
wfs.geometry.set_options(shift=(-60, -20))

plt.imshow(arr[0])
wfs.show_geometry()
# Out:
# ..\wfslib\wfs.py:106: UserWarning: WARNING: Set the geometry for the file!
#   warn("WARNING: Set the geometry for the file!", UserWarning)

# %%
wfs = WFSData('one_frame.h5', dataset_name = "image")
p = wfs.geometry.options
print(p)
wfs.geometry.set_options( shift = (-1,1), border = 6)
wfs.reference = 87
wfs.show_geometry(show_type = "offsets")
wfs.offsets()

#    plt.imshow(wfs[0][172])    
print(wfs[0].get_offset(130))
# Out:
# 2
# {'border': 8.0, 'cell_width': 32.0, 'start_point': [139, 99]}
# ..\wfslib\wfs.py:103: UserWarning: WARNING: Set the geometry for the file!
#   warn("WARNING: Set the geometry for the file!", UserWarning)
# [0. 0.]

# %%
# %matplotlib notebook

path = "data/bad_img2.tiff"

arr = np.array(Image.open(path))
arr = np.expand_dims(arr, 0)

plt.imshow(arr[0])
wfs = WFSData(arr)
wfs.geometry.set_options(shift=(63, -38),swap = True, rotate = 0.8)

#plt.imshow(arr[0])
wfs.show_geometry()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# ..\wfslib\wfs.py:108: UserWarning: WARNING: Set the geometry for the file!
#   warn("WARNING: Set the geometry for the file!", UserWarning)
# <img src="data:image/png;base64,..." width="998.8889153504084">

# %%
plt.imshow(wfs[0][24])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
wfs.geometry._rotate
# Out:
# 0.8

# %%
arr[0].ravel()
# Out:
# array([ 0,  0, 16, ...,  0,  0,  0], dtype=uint16)
